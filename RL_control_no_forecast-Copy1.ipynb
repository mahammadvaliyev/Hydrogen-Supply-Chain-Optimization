# %%
# =====================================================
# A) common_h2.py  (SHARED BY ALL METHODS) — notebook-friendly
# RL (no-forecast) adjusted to match your final COMMON + MPC constants/constraints
# so the ONLY difference is the control method (RL vs MPC vs RBC).
# =====================================================

import numpy as np

# -------------------------
# 1) Time settings
# -------------------------
CONTROL_HORIZON = 1
PREDICTION_HORIZON = 12
T_TOTAL = 168  # 1 week, 1-hour steps
DT_HOURS = 1.0

# -------------------------
# 2) System parameters (physical)
# -------------------------
ETA_CH = 0.95
ETA_DCH = 0.95

KWH_PER_KG = 50.0
ETA_ELEC = (DT_HOURS / KWH_PER_KG)  # kg per timestep per kW

SOC_MAX = 1000.0
P_BAT_MAX = 200.0
P_ELEC_MAX = 300.0
H_STORE_MAX = 1000.0

# Hydrogen storage throughput (kg/h)
H_CH_MAX = 10.0
H_DCH_MAX = 10.0

# Electrolyzer operational constraints
P_ELEC_MIN = 0.2 * P_ELEC_MAX  # 60 kW
RAMP_MAX = 60.0                # kW per hour

# Grid import limit (kW)
P_GRID_MAX = 250.0

# -------------------------
# 3) Economics (units aligned)
# -------------------------
C_GRID_BASE = 40.0  # unused (kept for completeness)
C_BATTERY = 0.03
C_ELEC = 0.01
C_HSTORE = 0.0005

H_PRICE = 10.0
CO2_ADDER = 0.02  # $/kWh

# -------------------------
# 4) Initial states
# -------------------------
SOC_INIT = 500.0
H_STORE_INIT = 20.0

# -------------------------
# 5) RNGs for disturbances (DO NOT re-init inside functions)
# -------------------------
_SOLAR_RNG = np.random.default_rng(0)
_PRICE_RNG = np.random.default_rng(1)
_DEMAND_RNG = np.random.default_rng(2)

# -------------------------
# 6) Real-time disturbance models (truth signals)
# -------------------------
def real_solar(t: int) -> float:
    """
    PV power available at time t [kW].
    Day/night half-sine + slow cloudiness + small noise.
    """
    hod = t % 24
    if hod < 6 or hod > 18:
        base = 0.0
    else:
        x = (hod - 6) / 12.0
        base = np.sin(np.pi * x)

    P_PV_PEAK = 300
    day = t // 24
    cloud = 0.75 + 0.20 * np.sin(2*np.pi*day/7.0)
    noise = _SOLAR_RNG.normal(0.0, 0.03)

    return float(max(0.0, P_PV_PEAK * base * (cloud + noise)))

def real_grid_price(t: int) -> float:
    """
    Electricity price [$/kWh].
    Time-of-use + rare spikes.
    """
    hod = t % 24
    if 0 <= hod < 6:
        p = 0.08
    elif 6 <= hod < 16:
        p = 0.12
    elif 16 <= hod < 21:
        p = 0.28
    else:
        p = 0.15

    if _PRICE_RNG.random() < 0.02:
        p *= 2.5

    return float(p)

def real_hydrogen_demand(t: int) -> float:
    """
    Hydrogen demand [kg/h] at time t.
    Scaled to match 300 kW electrolyzer (~6 kg/h max).
    """
    hod = t % 24
    base = 3.5 + 1.5*np.sin(2*np.pi*(hod-8)/24.0)  # ~2..5
    day = t // 24
    weekly = 0.3*np.sin(2*np.pi*day/7.0)
    noise = _DEMAND_RNG.normal(0.0, 0.25)

    return float(max(0.0, base + weekly + noise))

# -------------------------
# 7) Forecast model (used by MPC and RL+Forecast)
# (not used by RL no-forecast, but kept here for completeness)
# -------------------------
SIGMA_SOLAR0 = 10.0
SIGMA_PRICE0 = 0.02
SIGMA_DEMAND0 = 0.5
ALPHA = 0.8

def forecast_with_uncertainty(real_func, t_now: int, delta: int, rng: np.random.Generator, sigma0: float):
    std = float(sigma0 * np.sqrt(1.0 + ALPHA * float(delta)))
    value = float(real_func(t_now + delta) + rng.normal(0.0, std))
    return value, std

# -------------------------
# 8) Common logger + KPI tools
# -------------------------
def init_logs():
    return {k: [] for k in [
        "E_sb","E_sp","E_be","E_ge","P_elec",
        "H_prod","H_sales","H_es","H_est","H_ss",
        "SOC","H_store","solar"
    ]}

def compute_kpis(logs: dict) -> dict:
    time = np.arange(len(logs["E_sb"]))

    E_sb = np.asarray(logs["E_sb"], dtype=float)
    E_be = np.asarray(logs["E_be"], dtype=float)
    E_ge = np.asarray(logs["E_ge"], dtype=float)
    P_elec = np.asarray(logs["P_elec"], dtype=float)

    H_prod = np.asarray(logs["H_prod"], dtype=float)
    H_sales = np.asarray(logs["H_sales"], dtype=float)
    H_es = np.asarray(logs["H_es"], dtype=float)
    H_est = np.asarray(logs["H_est"], dtype=float)
    H_ss = np.asarray(logs["H_ss"], dtype=float)

    H_store = np.asarray(logs["H_store"], dtype=float)

    solar_to_battery = float(np.sum(E_sb))
    solar_to_electrolyzer = float(np.sum(P_elec - E_be - E_ge))  # approx (same as your common)
    battery_discharge = float(np.sum(E_be))
    grid_energy = float(np.sum(E_ge))
    electrolyzer_energy = float(np.sum(P_elec))

    hydrogen_produced = float(np.sum(H_prod))
    hydrogen_sold_total = float(np.sum(H_sales))
    hydrogen_sold_from_prod = float(np.sum(H_es))
    hydrogen_sold_from_storage = float(np.sum(H_ss))
    hydrogen_to_storage = float(np.sum(H_est))

    grid_prices = np.array([real_grid_price(int(t)) for t in time], dtype=float)
    grid_cost = float(np.sum(E_ge * (grid_prices + CO2_ADDER)))
    battery_cost = float(np.sum(C_BATTERY * (E_sb + E_be)))
    electrolyzer_cost = float(np.sum(C_ELEC * P_elec))
    storage_cost = float(np.sum(C_HSTORE * H_store))
    total_cost = float(grid_cost + battery_cost + electrolyzer_cost + storage_cost)

    revenue = float(np.sum(H_PRICE * H_sales))
    net_profit = float(revenue - total_cost)

    return {
        "Solar Used (E_se)": solar_to_electrolyzer,
        "Grid Energy Used (E_ge)": grid_energy,
        "Battery Charge (E_sb)": solar_to_battery,
        "Battery Discharge (E_be)": battery_discharge,
        "Electrolyzer Energy": electrolyzer_energy,

        "Hydrogen Produced": hydrogen_produced,
        "Hydrogen Sold (Total)": hydrogen_sold_total,
        "Hydrogen Sold from Production (H_es)": hydrogen_sold_from_prod,
        "Hydrogen Sold from Storage (H_ss)": hydrogen_sold_from_storage,
        "Hydrogen Stored (H_est)": hydrogen_to_storage,

        "Revenue ($)": revenue,
        "Grid Cost ($)": grid_cost,
        "Battery Cost ($)": battery_cost,
        "Electrolyzer Cost ($)": electrolyzer_cost,
        "Storage Cost ($)": storage_cost,
        "Total Cost ($)": total_cost,
        "Net Profit ($)": net_profit,

        "H₂ Utilization (%)": float(100 * hydrogen_sold_total / (hydrogen_produced + H_STORE_INIT)) if hydrogen_produced > 0 else 0.0
    }

import matplotlib.pyplot as plt
import numpy as np

def plot_kpis(kpi_values: dict, title_suffix: str = "") -> None:
    """
    Publication-ready KPI plots (identical formatting across RBC/MPC/RL).
    - Removes efficiency panel
    - Thicker bar outlines (print-friendly)
    - Lighter grid
    - Cleaner numeric annotations
    """

    categories = {
        "Energy (kWh)": [
            "Solar Used (E_se)", "Grid Energy Used (E_ge)",
            "Battery Charge (E_sb)", "Battery Discharge (E_be)",
            "Electrolyzer Energy"
        ],
        "Hydrogen (kg)": [
            "Hydrogen Produced", "Hydrogen Sold (Total)",
            "Hydrogen Sold from Production (H_es)",
            "Hydrogen Sold from Storage (H_ss)",
            "Hydrogen Stored (H_est)"
        ],
        "Cost & Revenue ($)": [
            "Revenue ($)", "Grid Cost ($)", "Battery Cost ($)",
            "Electrolyzer Cost ($)", "Storage Cost ($)",
            "Total Cost ($)", "Net Profit ($)"
        ]
    }

    fig, axs = plt.subplots(len(categories), 1, figsize=(13, 14))
    if len(categories) == 1:
        axs = [axs]

    for ax, (title, keys) in zip(axs, categories.items()):
        values = [float(kpi_values[k]) for k in keys]

        bars = ax.barh(
            keys,
            values,
            edgecolor="black",
            linewidth=1.2,
        )

        ax.set_title(f"{title} {title_suffix}".strip(), fontsize=13)
        ax.set_xlabel(title, fontsize=12)
        ax.grid(True, axis="x", linestyle="--", alpha=0.25)
        ax.set_axisbelow(True)
        ax.tick_params(axis="y", labelsize=11)
        ax.tick_params(axis="x", labelsize=11)

        xpad = 0.01 * (max(abs(v) for v in values) if values else 1.0)

        for bar in bars:
            width = bar.get_width()
            if abs(width) >= 1000:
                label = f"{width:,.0f}"
            elif abs(width) >= 10:
                label = f"{width:.1f}"
            else:
                label = f"{width:.2f}"

            ax.text(
                width + (xpad if width >= 0 else -xpad),
                bar.get_y() + bar.get_height() / 2.0,
                label,
                va="center",
                ha="left" if width >= 0 else "right",
                fontsize=10
            )

    plt.tight_layout()
    plt.show()

# %%
# =====================================================
# D) rl_no_forecast.py  (METHOD 3: RL without Forecast)
# Notebook-friendly, block-by-block
# Requires:
#   pip install "gymnasium>=0.29" "stable-baselines3>=2.2" "torch>=2.0"
# =====================================================

import gymnasium as gym
from gymnasium import spaces

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.utils import set_random_seed


# -------------------------
# Feasibility layer (action -> feasible physical controls)
# Matches MPC/RBC constraints:
#   - P_GRID_MAX cap
#   - H_CH_MAX / H_DCH_MAX caps
#   - electrolyzer min-load + ON/OFF via action
#   - ramp constraint enforced with previous power
#   - implicit PV curtailment (spill) handled by "unused solar" (not logged)
# -------------------------
def feasibility_layer_no_forecast(
    solar: float,
    price: float,
    demand: float,
    SOC: float,
    H_store: float,
    P_prev: float,
    action: np.ndarray,
):
    """
    Action in [0,1]^3:
      a0 u_on   : ON/OFF (>=0.5 means "intend ON")
      a1 u_pe   : electrolyzer load fraction in [0,1] (applied if ON)
      a2 u_batt : battery mode in [0,1] -> [-1,1] (charge..discharge)

    Returns dict with feasible flows + next states, all aligned with MPC/RBC constraints.

    EDIT: Allocate solar to electrolyzer FIRST; battery charges only from leftover solar.
    """
    a0 = float(np.clip(action[0], 0.0, 1.0))
    a1 = float(np.clip(action[1], 0.0, 1.0))
    a2 = float(np.clip(action[2], 0.0, 1.0))

    intend_on = (a0 >= 0.5)

    # ---- Electrolyzer target with min-load when ON ----
    if intend_on:
        P_target = P_ELEC_MIN + a1 * (P_ELEC_MAX - P_ELEC_MIN)
    else:
        P_target = 0.0

    # ---- Ramp constraint applied to target ----
    P_target = float(np.clip(
        P_target,
        max(0.0, P_prev - RAMP_MAX),
        min(P_ELEC_MAX, P_prev + RAMP_MAX)
    ))

    # ---- Battery mode ----
    batt_mode = 2.0 * (a2 - 0.5)  # [-1,1], -1 charge, +1 discharge
    charge_fraction = max(-batt_mode, 0.0)      # 0..1
    discharge_fraction = max(batt_mode, 0.0)    # 0..1

    # ---------- Use solar for electrolyzer FIRST ----------
    P_from_solar = min(solar, P_target)
    P_elec = P_from_solar
    solar_rem = max(solar - P_from_solar, 0.0)

    # ---------- Battery charge ONLY from remaining solar ----------
    SOC_headroom = max(SOC_MAX - SOC, 0.0)
    E_sb_cap_soc = SOC_headroom / max(ETA_CH, 1e-9)
    E_sb_cap = min(P_BAT_MAX, E_sb_cap_soc)

    E_sb = min(E_sb_cap, solar_rem * charge_fraction)

    # PV spill after optional charging
    E_sp = max(solar_rem - E_sb, 0.0)

    # ---------- Battery discharge to meet P_target ----------
    E_be_cap_soc = SOC * ETA_DCH
    E_be_cap = min(P_BAT_MAX, E_be_cap_soc)

    needed = max(P_target - P_elec, 0.0)
    E_be = min(needed, E_be_cap * discharge_fraction)
    P_elec += E_be

    # ---------- Grid fills remaining gap (capped by P_GRID_MAX) ----------
    needed = max(P_target - P_elec, 0.0)
    E_ge = min(needed, P_GRID_MAX)
    P_elec += E_ge

    # If we intended ON, but can't reach min-load (e.g., ramp/limits), turn off
    if intend_on and (0.0 < P_elec < P_ELEC_MIN):
        P_elec = 0.0
        E_ge = 0.0
        E_be = 0.0
        # keep E_sb as chosen (still can charge battery from PV)

    # hard safety caps
    P_elec = float(np.clip(P_elec, 0.0, P_ELEC_MAX))
    E_sb = float(np.clip(E_sb, 0.0, P_BAT_MAX))
    E_be = float(np.clip(E_be, 0.0, P_BAT_MAX))
    E_ge = float(np.clip(E_ge, 0.0, P_GRID_MAX))
    E_sp = float(max(0.0, E_sp))

    # ---------- Hydrogen production ----------
    H_prod = float(ETA_ELEC * P_elec)

    # ---------- Sell from production first ----------
    H_es = float(min(H_prod, demand))
    demand_left = float(max(demand - H_es, 0.0))

    # ---------- Sell from storage (throughput + inventory) ----------
    H_ss = float(min(H_store, demand_left, H_DCH_MAX))
    H_sales = float(H_es + H_ss)

    # ---------- Store surplus (throughput + headroom) ----------
    surplus = float(max(H_prod - H_es, 0.0))
    headroom = float(max(H_STORE_MAX - H_store, 0.0))
    H_est = float(min(surplus, headroom, H_CH_MAX))

    # ---------- State updates ----------
    SOC_new = float(SOC + ETA_CH * E_sb - E_be / max(ETA_DCH, 1e-9))
    SOC_new = float(np.clip(SOC_new, 0.0, SOC_MAX))

    H_store_new = float(H_store + H_est - H_ss)
    H_store_new = float(np.clip(H_store_new, 0.0, H_STORE_MAX))

    return dict(
        E_sb=E_sb, E_sp=E_sp, E_be=E_be, E_ge=E_ge, P_elec=P_elec,
        H_prod=H_prod, H_es=H_es, H_est=H_est, H_ss=H_ss,
        H_sales=H_sales, SOC_new=SOC_new, H_store_new=H_store_new,
        P_next=P_elec
    )

# %%
# -------------------------
# Gym environment (no forecast in observation)
# Observation includes only current state + current disturbances (no future).
# Also includes normalized previous electrolyzer power to help learn ramping.
# -------------------------
class HydrogenEnvNoForecast(gym.Env):
    """
    Observation (normalized to [0,1]):
      [ SOC/SOC_MAX,
        H_store/H_STORE_MAX,
        P_prev/P_ELEC_MAX,
        solar/solar_scale,
        price/price_scale,
        demand/demand_scale ]

    Action:
      3D continuous in [0,1]^3:
        [u_on, u_pe, u_batt]
    """
    metadata = {"render_modes": []}

    def __init__(self, T: int = 168, seed: int = 0):
        super().__init__()
        self.T = int(T)
        self.rng = np.random.default_rng(seed)

        # normalization scales (fixed; not "tuned" between methods)
        self.solar_scale = 300.0   # solar peak ~300
        self.price_scale = 0.75    # spike can go higher; we clip to 1 anyway
        self.demand_scale = 8.0    # demand ~2..5; safe upper scale

        self.observation_space = spaces.Box(
            low=0.0, high=1.0, shape=(6,), dtype=np.float32
        )
        self.action_space = spaces.Box(
            low=0.0, high=1.0, shape=(3,), dtype=np.float32
        )

        self.t = 0
        self.SOC = float(SOC_INIT)
        self.H_store = float(H_STORE_INIT)
        self.P_prev = 0.0
        self.logs = init_logs()

    def _obs(self):
        s = float(real_solar(self.t))
        p = float(real_grid_price(self.t))
        d = float(real_hydrogen_demand(self.t))
        return np.array([
            self.SOC / SOC_MAX,
            self.H_store / H_STORE_MAX,
            self.P_prev / P_ELEC_MAX,
            np.clip(s / self.solar_scale, 0.0, 1.0),
            np.clip(p / self.price_scale, 0.0, 1.0),
            np.clip(d / self.demand_scale, 0.0, 1.0),
        ], dtype=np.float32)

    def reset(self, seed=None, options=None):
        if seed is not None:
            self.rng = np.random.default_rng(seed)
        self.t = 0
        self.SOC = float(SOC_INIT)
        self.H_store = float(H_STORE_INIT)
        self.P_prev = 0.0
        self.logs = init_logs()
        return self._obs(), {}

    def step(self, action):
        # real (truth) disturbances at current time
        s = float(real_solar(self.t))
        p = float(real_grid_price(self.t))
        d = float(real_hydrogen_demand(self.t))

        out = feasibility_layer_no_forecast(
            solar=s, price=p, demand=d,
            SOC=self.SOC, H_store=self.H_store,
            P_prev=self.P_prev,
            action=action
        )

        # reward aligned with MPC objective: per-step profit
        revenue = H_PRICE * out["H_sales"]
        cost_grid = (p + CO2_ADDER) * out["E_ge"]
        cost_batt = C_BATTERY * (out["E_sb"] + out["E_be"])
        cost_elec = C_ELEC * out["P_elec"]
        cost_store = C_HSTORE * out["H_store_new"]
        reward = float(revenue - (cost_grid + cost_batt + cost_elec + cost_store))

        # log PRE-update SOC/H_store (match RBC/MPC convention)
        for k in ["E_sb","E_sp","E_be","E_ge","P_elec","H_prod","H_sales","H_es","H_est","H_ss"]:
            self.logs[k].append(float(out[k]))
        self.logs["SOC"].append(float(self.SOC))
        self.logs["H_store"].append(float(self.H_store))
        self.logs["solar"].append(float(s))

        # advance state
        self.SOC = float(out["SOC_new"])
        self.H_store = float(out["H_store_new"])
        self.P_prev = float(out["P_next"])
        self.t += 1

        terminated = self.t >= self.T
        obs = self._obs() if not terminated else np.zeros((6,), dtype=np.float32)
        return obs, reward, terminated, False, {}

# %%
# =========================
# RL (no-forecast) — TRAINING
# =========================
def train_rl_no_forecast(
    train_steps: int = 200_000,
    seed: int = 42,
    learning_rate: float = 3e-4,
    n_steps: int = 2048,
    batch_size: int = 256,
    ent_coef=0.01,
    gamma: float = 0.99,
    verbose: int = 1,
    
):
    set_random_seed(seed)
    env = DummyVecEnv([lambda: HydrogenEnvNoForecast(T=T_TOTAL, seed=seed)])

    model = PPO(
        "MlpPolicy",
        env,
        verbose=verbose,
        learning_rate=learning_rate,
        n_steps=n_steps,
        batch_size=batch_size,
        gamma=gamma,
    )
    model.learn(total_timesteps=int(train_steps))
    return model

# %%
# =========================
# RL (no-forecast) — EVALUATION / LOGGING
# =========================
def eval_rl_no_forecast(model, seed: int = 123):
    eval_env = HydrogenEnvNoForecast(T=T_TOTAL, seed=seed)
    obs, _ = eval_env.reset()

    done = False
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, r, done, trunc, info = eval_env.step(action)

    return eval_env.logs

# %%
# =========================
# RL (no-forecast) — KPI REPORT
# =========================
def report_rl_results(logs, title_suffix="(RL no-forecast)"):
    kpis = compute_kpis(logs)

    print("\n===== RL KPIs =====")
    for k, v in kpis.items():
        print(f"{k:40s}: {v:.2f}")

    plot_kpis(kpis, title_suffix=title_suffix)
    return kpis

# %%
# =========================
# Example workflow
# =========================
# --- train ---
model_rl_nf = train_rl_no_forecast(train_steps=200_000, seed=42, verbose=1)
# Out:
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 1905 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1628        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013301318 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.00101     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.29e+03    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0118     |
# |    std                  | 1           |
# |    value_loss           | 3.19e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1580        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011339234 |
# |    clip_fraction        | 0.0854      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | -0.007      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.03e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0099     |
# |    std                  | 1           |
# |    value_loss           | 4.23e+03    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1557       |
# |    iterations           | 4          |
# |    time_elapsed         | 5          |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00919694 |
# |    clip_fraction        | 0.0493     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.27      |
# |    explained_variance   | -0.0116    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.97e+03   |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.00712   |
# |    std                  | 1          |
# |    value_loss           | 5.62e+03   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1542        |
# |    iterations           | 5           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010655683 |
# |    clip_fraction        | 0.0702      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.28       |
# |    explained_variance   | -0.0109     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.76e+03    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00885    |
# |    std                  | 1.01        |
# |    value_loss           | 7.27e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1537        |
# |    iterations           | 6           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011325066 |
# |    clip_fraction        | 0.0829      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.28       |
# |    explained_variance   | -0.00796    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.99e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0094     |
# |    std                  | 1.01        |
# |    value_loss           | 9.49e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1536        |
# |    iterations           | 7           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010284576 |
# |    clip_fraction        | 0.0796      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.28       |
# |    explained_variance   | -0.00451    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.21e+03    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00992    |
# |    std                  | 1.01        |
# |    value_loss           | 1.35e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1534        |
# |    iterations           | 8           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009291191 |
# |    clip_fraction        | 0.0634      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.28       |
# |    explained_variance   | -0.00216    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.51e+03    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00853    |
# |    std                  | 1.01        |
# |    value_loss           | 1.58e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1532        |
# |    iterations           | 9           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008841541 |
# |    clip_fraction        | 0.0552      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | 0.000921    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.13e+04    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00814    |
# |    std                  | 1           |
# |    value_loss           | 2.2e+04     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1531        |
# |    iterations           | 10          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.011024099 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.000738    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.01e+04    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.012      |
# |    std                  | 1           |
# |    value_loss           | 2.13e+04    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1528       |
# |    iterations           | 11         |
# |    time_elapsed         | 14         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.00873797 |
# |    clip_fraction        | 0.0593     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.26      |
# |    explained_variance   | 0.000911   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.25e+04   |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.00786   |
# |    std                  | 1          |
# |    value_loss           | 2.71e+04   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1528         |
# |    iterations           | 12           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0031152982 |
# |    clip_fraction        | 0.00474      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0.001        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.55e+04     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0026      |
# |    std                  | 0.996        |
# |    value_loss           | 2.92e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1528        |
# |    iterations           | 13          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.002541617 |
# |    clip_fraction        | 0.00146     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.000555    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.63e+04    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00154    |
# |    std                  | 0.997       |
# |    value_loss           | 3.28e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1527         |
# |    iterations           | 14           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0045550577 |
# |    clip_fraction        | 0.014        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0.000517     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.73e+04     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00332     |
# |    std                  | 0.999        |
# |    value_loss           | 3.41e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1528         |
# |    iterations           | 15           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0039311526 |
# |    clip_fraction        | 0.0118       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0.000149     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.45e+04     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00281     |
# |    std                  | 0.996        |
# |    value_loss           | 3.26e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1525        |
# |    iterations           | 16          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.006388693 |
# |    clip_fraction        | 0.0299      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.000229    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.8e+04     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00495    |
# |    std                  | 0.994       |
# |    value_loss           | 3.5e+04     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1508         |
# |    iterations           | 17           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0016064766 |
# |    clip_fraction        | 0.000684     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.24        |
# |    explained_variance   | 1.63e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.71e+04     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00119     |
# |    std                  | 0.995        |
# |    value_loss           | 3.51e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1505        |
# |    iterations           | 18          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.002407914 |
# |    clip_fraction        | 0.00205     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | -1.92e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.96e+04    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00117    |
# |    std                  | 0.997       |
# |    value_loss           | 3.77e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1499        |
# |    iterations           | 19          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.004285304 |
# |    clip_fraction        | 0.00723     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | -2.17e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.83e+04    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00268    |
# |    std                  | 0.997       |
# |    value_loss           | 3.63e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1498         |
# |    iterations           | 20           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0041444013 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 3.23e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.73e+04     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00329     |
# |    std                  | 0.998        |
# |    value_loss           | 3.44e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1493         |
# |    iterations           | 21           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0041413303 |
# |    clip_fraction        | 0.0111       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 4.09e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.82e+04     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00262     |
# |    std                  | 0.998        |
# |    value_loss           | 3.69e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1486         |
# |    iterations           | 22           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0038848016 |
# |    clip_fraction        | 0.00649      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.24        |
# |    explained_variance   | 5.81e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.62e+04     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00228     |
# |    std                  | 0.993        |
# |    value_loss           | 3.5e+04      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1486         |
# |    iterations           | 23           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0011368159 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.23        |
# |    explained_variance   | 3.17e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.56e+04     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000837    |
# |    std                  | 0.991        |
# |    value_loss           | 3.54e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1485        |
# |    iterations           | 24          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.004432096 |
# |    clip_fraction        | 0.0106      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.22       |
# |    explained_variance   | 5.48e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.86e+04    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00289    |
# |    std                  | 0.988       |
# |    value_loss           | 3.71e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1486        |
# |    iterations           | 25          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.004099599 |
# |    clip_fraction        | 0.017       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.22       |
# |    explained_variance   | 1.45e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.74e+04    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00263    |
# |    std                  | 0.987       |
# |    value_loss           | 3.47e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1484         |
# |    iterations           | 26           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0034443517 |
# |    clip_fraction        | 0.00522      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.21        |
# |    explained_variance   | 4.13e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2e+04        |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00223     |
# |    std                  | 0.983        |
# |    value_loss           | 3.9e+04      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1485         |
# |    iterations           | 27           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0060110954 |
# |    clip_fraction        | 0.0206       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.2         |
# |    explained_variance   | -1.07e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.98e+04     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00415     |
# |    std                  | 0.983        |
# |    value_loss           | 3.87e+04     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1486          |
# |    iterations           | 28            |
# |    time_elapsed         | 38            |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 0.00027231427 |
# |    clip_fraction        | 4.88e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.21         |
# |    explained_variance   | 1.3e-05       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.83e+04      |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -0.00084      |
# |    std                  | 0.988         |
# |    value_loss           | 3.58e+04      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1486         |
# |    iterations           | 29           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0062887874 |
# |    clip_fraction        | 0.0339       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.22        |
# |    explained_variance   | 3.99e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.01e+04     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00483     |
# |    std                  | 0.987        |
# |    value_loss           | 3.89e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1482         |
# |    iterations           | 30           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0034307225 |
# |    clip_fraction        | 0.0041       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.21        |
# |    explained_variance   | 2.68e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.95e+04     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00152     |
# |    std                  | 0.986        |
# |    value_loss           | 3.88e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1483         |
# |    iterations           | 31           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0038038897 |
# |    clip_fraction        | 0.0103       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.21        |
# |    explained_variance   | 1.15e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.91e+04     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00202     |
# |    std                  | 0.983        |
# |    value_loss           | 3.83e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1483         |
# |    iterations           | 32           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0021208161 |
# |    clip_fraction        | 0.00225      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.2         |
# |    explained_variance   | 4.39e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.66e+04     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00116     |
# |    std                  | 0.981        |
# |    value_loss           | 3.59e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1483        |
# |    iterations           | 33          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.003935804 |
# |    clip_fraction        | 0.0113      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.19       |
# |    explained_variance   | -2.86e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.81e+04    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00299    |
# |    std                  | 0.974       |
# |    value_loss           | 3.59e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1482        |
# |    iterations           | 34          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.005436199 |
# |    clip_fraction        | 0.0199      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 6.62e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.87e+04    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00424    |
# |    std                  | 0.969       |
# |    value_loss           | 3.71e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1481        |
# |    iterations           | 35          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.001255873 |
# |    clip_fraction        | 9.77e-05    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 2.54e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.68e+04    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.000624   |
# |    std                  | 0.967       |
# |    value_loss           | 3.36e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1482        |
# |    iterations           | 36          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.004083435 |
# |    clip_fraction        | 0.0107      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | 3.09e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.64e+04    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00235    |
# |    std                  | 0.967       |
# |    value_loss           | 3.34e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1482         |
# |    iterations           | 37           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0043616826 |
# |    clip_fraction        | 0.0194       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.14        |
# |    explained_variance   | 1.27e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.64e+04     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.0033      |
# |    std                  | 0.962        |
# |    value_loss           | 3.33e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1482        |
# |    iterations           | 38          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.003669734 |
# |    clip_fraction        | 0.00439     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.13       |
# |    explained_variance   | -6.2e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.92e+04    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00178    |
# |    std                  | 0.961       |
# |    value_loss           | 3.84e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1481         |
# |    iterations           | 39           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0040730755 |
# |    clip_fraction        | 0.00933      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.13        |
# |    explained_variance   | 8.29e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.85e+04     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00269     |
# |    std                  | 0.956        |
# |    value_loss           | 3.56e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1481         |
# |    iterations           | 40           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0031180026 |
# |    clip_fraction        | 0.00435      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.12        |
# |    explained_variance   | 2.35e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.46e+04     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00158     |
# |    std                  | 0.956        |
# |    value_loss           | 3.35e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1482         |
# |    iterations           | 41           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0058200574 |
# |    clip_fraction        | 0.0266       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.12        |
# |    explained_variance   | 1.75e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.79e+04     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00358     |
# |    std                  | 0.955        |
# |    value_loss           | 3.86e+04     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1482       |
# |    iterations           | 42         |
# |    time_elapsed         | 58         |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.00457541 |
# |    clip_fraction        | 0.0104     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.11      |
# |    explained_variance   | -2.74e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.76e+04   |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.00252   |
# |    std                  | 0.954      |
# |    value_loss           | 3.59e+04   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1483         |
# |    iterations           | 43           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0040064803 |
# |    clip_fraction        | 0.0114       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.1         |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.9e+04      |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00251     |
# |    std                  | 0.951        |
# |    value_loss           | 3.91e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1483         |
# |    iterations           | 44           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0005032301 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.09        |
# |    explained_variance   | -2.62e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.9e+04      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.000628    |
# |    std                  | 0.949        |
# |    value_loss           | 3.73e+04     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1484       |
# |    iterations           | 45         |
# |    time_elapsed         | 62         |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.00261455 |
# |    clip_fraction        | 0.00151    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.09      |
# |    explained_variance   | -1.07e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.05e+04   |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.00111   |
# |    std                  | 0.947      |
# |    value_loss           | 3.82e+04   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1480         |
# |    iterations           | 46           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0028104784 |
# |    clip_fraction        | 0.0063       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.08        |
# |    explained_variance   | 3.64e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.84e+04     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00163     |
# |    std                  | 0.945        |
# |    value_loss           | 3.63e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1481         |
# |    iterations           | 47           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0046982616 |
# |    clip_fraction        | 0.0156       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.07        |
# |    explained_variance   | -4.77e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.83e+04     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00308     |
# |    std                  | 0.941        |
# |    value_loss           | 3.65e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1482         |
# |    iterations           | 48           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0038158293 |
# |    clip_fraction        | 0.00996      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.06        |
# |    explained_variance   | 6.97e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.48e+04     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00323     |
# |    std                  | 0.937        |
# |    value_loss           | 3.31e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1482        |
# |    iterations           | 49          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.004154886 |
# |    clip_fraction        | 0.0187      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.05       |
# |    explained_variance   | 8.7e-06     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.02e+04    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00362    |
# |    std                  | 0.933       |
# |    value_loss           | 4.12e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1481        |
# |    iterations           | 50          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.004754432 |
# |    clip_fraction        | 0.027       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.03       |
# |    explained_variance   | 2.56e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.76e+04    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00435    |
# |    std                  | 0.925       |
# |    value_loss           | 3.29e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1481         |
# |    iterations           | 51           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0013250269 |
# |    clip_fraction        | 0.000146     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.01        |
# |    explained_variance   | 1.28e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.88e+04     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.000748    |
# |    std                  | 0.922        |
# |    value_loss           | 3.73e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1481         |
# |    iterations           | 52           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0033483345 |
# |    clip_fraction        | 0.00596      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4           |
# |    explained_variance   | 6.97e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.83e+04     |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.000974    |
# |    std                  | 0.92         |
# |    value_loss           | 3.68e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1482        |
# |    iterations           | 53          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.003704948 |
# |    clip_fraction        | 0.0161      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.99       |
# |    explained_variance   | 8.29e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.68e+04    |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00246    |
# |    std                  | 0.916       |
# |    value_loss           | 3.55e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1480        |
# |    iterations           | 54          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.004930379 |
# |    clip_fraction        | 0.0374      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.98       |
# |    explained_variance   | 1.11e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.89e+04    |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00477    |
# |    std                  | 0.915       |
# |    value_loss           | 3.7e+04     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1481         |
# |    iterations           | 55           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0029639737 |
# |    clip_fraction        | 0.00322      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.97        |
# |    explained_variance   | 9.78e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.8e+04      |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00226     |
# |    std                  | 0.909        |
# |    value_loss           | 3.9e+04      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1481        |
# |    iterations           | 56          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.005422096 |
# |    clip_fraction        | 0.0362      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.96       |
# |    explained_variance   | 1.73e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.01e+04    |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.00528    |
# |    std                  | 0.908       |
# |    value_loss           | 3.81e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1482         |
# |    iterations           | 57           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0046839262 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.96        |
# |    explained_variance   | -2.86e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.98e+04     |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.00196     |
# |    std                  | 0.908        |
# |    value_loss           | 3.89e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1482         |
# |    iterations           | 58           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0018871234 |
# |    clip_fraction        | 0.000781     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.95        |
# |    explained_variance   | 1.67e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2e+04        |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.000821    |
# |    std                  | 0.907        |
# |    value_loss           | 4.18e+04     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1483       |
# |    iterations           | 59         |
# |    time_elapsed         | 81         |
# |    total_timesteps      | 120832     |
# | train/                  |            |
# |    approx_kl            | 0.00457076 |
# |    clip_fraction        | 0.0209     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.95      |
# |    explained_variance   | 1.61e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.73e+04   |
# |    n_updates            | 580        |
# |    policy_gradient_loss | -0.00258   |
# |    std                  | 0.905      |
# |    value_loss           | 3.68e+04   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1483         |
# |    iterations           | 60           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0042920066 |
# |    clip_fraction        | 0.0207       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.94        |
# |    explained_variance   | -4.77e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.05e+04     |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.00282     |
# |    std                  | 0.902        |
# |    value_loss           | 4.34e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1484        |
# |    iterations           | 61          |
# ...
# |    total_timesteps      | 161792       |
# | train/                  |              |
# |    approx_kl            | 0.0033407963 |
# |    clip_fraction        | 0.00576      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.77        |
# |    explained_variance   | 2.38e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.87e+04     |
# |    n_updates            | 780          |
# |    policy_gradient_loss | -0.00131     |
# |    std                  | 0.854        |
# |    value_loss           | 4.05e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1490         |
# |    iterations           | 80           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0055709053 |
# |    clip_fraction        | 0.0486       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.76        |
# |    explained_variance   | -2.15e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.08e+04     |
# |    n_updates            | 790          |
# |    policy_gradient_loss | -0.00504     |
# |    std                  | 0.852        |
# |    value_loss           | 4.2e+04      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1491         |
# |    iterations           | 81           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0041265083 |
# |    clip_fraction        | 0.0189       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.75        |
# |    explained_variance   | 7.75e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.2e+04      |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.00284     |
# |    std                  | 0.848        |
# |    value_loss           | 4.3e+04      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1491        |
# |    iterations           | 82          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.003954919 |
# |    clip_fraction        | 0.0228      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.73       |
# |    explained_variance   | -9.54e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.05e+04    |
# |    n_updates            | 810         |
# |    policy_gradient_loss | -0.00366    |
# |    std                  | 0.843       |
# |    value_loss           | 4.23e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1491         |
# |    iterations           | 83           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 169984       |
# | train/                  |              |
# |    approx_kl            | 0.0053609954 |
# |    clip_fraction        | 0.0211       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.72        |
# |    explained_variance   | 1.19e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.03e+04     |
# |    n_updates            | 820          |
# |    policy_gradient_loss | -0.00403     |
# |    std                  | 0.841        |
# |    value_loss           | 4.2e+04      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1491        |
# |    iterations           | 84          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.004862697 |
# |    clip_fraction        | 0.029       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.71       |
# |    explained_variance   | 7.75e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.12e+04    |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.0035     |
# |    std                  | 0.838       |
# |    value_loss           | 4.29e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1492         |
# |    iterations           | 85           |
# |    time_elapsed         | 116          |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0024532028 |
# |    clip_fraction        | 0.00264      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.71        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.36e+04     |
# |    n_updates            | 840          |
# |    policy_gradient_loss | -0.00119     |
# |    std                  | 0.839        |
# |    value_loss           | 4.56e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1492        |
# |    iterations           | 86          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.004053049 |
# |    clip_fraction        | 0.0193      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.71       |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.27e+04    |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.0026     |
# |    std                  | 0.84        |
# |    value_loss           | 4.27e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1492         |
# |    iterations           | 87           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0027010809 |
# |    clip_fraction        | 0.014        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.72        |
# |    explained_variance   | -3.58e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.06e+04     |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.00224     |
# |    std                  | 0.841        |
# |    value_loss           | 4.1e+04      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1492         |
# |    iterations           | 88           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0029881964 |
# |    clip_fraction        | 0.00654      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.71        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.85e+04     |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.00112     |
# |    std                  | 0.84         |
# |    value_loss           | 4.26e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1491        |
# |    iterations           | 89          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.003688947 |
# |    clip_fraction        | 0.0159      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.7        |
# |    explained_variance   | 5.36e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.91e+04    |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.00212    |
# |    std                  | 0.833       |
# |    value_loss           | 4.19e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1491         |
# |    iterations           | 90           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0046266066 |
# |    clip_fraction        | 0.0168       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.69        |
# |    explained_variance   | 8.94e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.19e+04     |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.00248     |
# |    std                  | 0.833        |
# |    value_loss           | 4.29e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1492         |
# |    iterations           | 91           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0057150945 |
# |    clip_fraction        | 0.0354       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.68        |
# |    explained_variance   | 7.75e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.26e+04     |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.00429     |
# |    std                  | 0.828        |
# |    value_loss           | 4.5e+04      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1492         |
# |    iterations           | 92           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0033982308 |
# |    clip_fraction        | 0.00693      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.67        |
# |    explained_variance   | 4.77e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.92e+04     |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.00163     |
# |    std                  | 0.829        |
# |    value_loss           | 4.31e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1492        |
# |    iterations           | 93          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.004437469 |
# |    clip_fraction        | 0.0195      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.67       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.17e+04    |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.00326    |
# |    std                  | 0.827       |
# |    value_loss           | 4.43e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1492         |
# |    iterations           | 94           |
# |    time_elapsed         | 128          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0052941446 |
# |    clip_fraction        | 0.0255       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.66        |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2e+04        |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.00353     |
# |    std                  | 0.825        |
# |    value_loss           | 4.23e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1493         |
# |    iterations           | 95           |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0041656336 |
# |    clip_fraction        | 0.0203       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.65        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.32e+04     |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -0.00201     |
# |    std                  | 0.825        |
# |    value_loss           | 4.31e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1493        |
# |    iterations           | 96          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.003686286 |
# |    clip_fraction        | 0.0123      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.65       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.17e+04    |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.00207    |
# |    std                  | 0.821       |
# |    value_loss           | 4.49e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1493         |
# |    iterations           | 97           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0010828461 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.64        |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.34e+04     |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.00125     |
# |    std                  | 0.82         |
# |    value_loss           | 4.57e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1493        |
# |    iterations           | 98          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.005527775 |
# |    clip_fraction        | 0.0402      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.63       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.15e+04    |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.00394    |
# |    std                  | 0.819       |
# |    value_loss           | 4.28e+04    |
# -----------------------------------------

# %%
# --- eval ---
logs_rl_nf = eval_rl_no_forecast(model_rl_nf, seed=123)

# %%
# --- report ---
kpis_rl_nf = report_rl_results(logs_rl_nf, title_suffix="(RL no-forecast)")
# Out:
# ===== RL KPIs =====
# Solar Used (E_se)                       : 11885.58
# Grid Energy Used (E_ge)                 : 9723.68
# Battery Charge (E_sb)                   : 0.00
# Battery Discharge (E_be)                : 474.90
# Electrolyzer Energy                     : 22084.15
# Hydrogen Produced                       : 441.68
# Hydrogen Sold (Total)                   : 461.68
# Hydrogen Sold from Production (H_es)    : 418.35
# Hydrogen Sold from Storage (H_ss)       : 43.33
# Hydrogen Stored (H_est)                 : 23.33
# Revenue ($)                             : 4616.83
# Grid Cost ($)                           : 1562.35
# Battery Cost ($)                        : 14.25
# Electrolyzer Cost ($)                   : 220.84
# Storage Cost ($)                        : 0.24
# Total Cost ($)                          : 1797.67
# Net Profit ($)                          : 2819.16
# H₂ Utilization (%)                      : 100.00

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_fig6_rl_timeseries(logs_rl, savepath=None, show=True,
                            title="Figure 6. RL time-series operational behavior"):
    """
    Same Figure-6 plotting style as MPC, but for RL logs.
    Expects logs_rl keys: "solar", "P_elec", "E_ge", "SOC", "H_store"
    Requires: real_grid_price(t) available in scope.
    """

    t = np.arange(len(logs_rl["P_elec"]))

    solar  = np.asarray(logs_rl["solar"], dtype=float)
    P_elec = np.asarray(logs_rl["P_elec"], dtype=float)
    E_ge   = np.asarray(logs_rl["E_ge"], dtype=float)
    SOC    = np.asarray(logs_rl["SOC"], dtype=float)
    H_store= np.asarray(logs_rl["H_store"], dtype=float)

    price = np.array([real_grid_price(int(k)) for k in t], dtype=float)

    # Color palette (identical to MPC/RBC for consistency)
    COL_SOLAR = "#1f77b4"
    COL_PRICE = "#ff7f0e"
    COL_ELEC  = "#2ca02c"
    COL_GRID  = "#d62728"
    COL_SOC   = "#9467bd"
    COL_H2    = "#8c564b"

    fig, axs = plt.subplots(3, 1, figsize=(13, 8), sharex=True)
    fig.suptitle(title, y=0.98)

    # -------------------------
    # (a) Solar + Price
    # -------------------------
    ax = axs[0]
    l1 = ax.plot(t, solar, color=COL_SOLAR, linewidth=2.2,
                 label="Solar availability $S_t$ [kW]")
    ax.set_ylabel("Solar [kW]")
    ax.grid(True, alpha=0.2, linestyle="--")

    ax_r = ax.twinx()
    l2 = ax_r.plot(t, price, color=COL_PRICE, linestyle="--", linewidth=2.0,
                   label="Grid price $\\pi_t$ [$/kWh]")
    ax_r.set_ylabel("Price [$/kWh]")

    # -------------------------
    # (b) Electrolyzer + Grid
    # -------------------------
    ax = axs[1]
    l3 = ax.plot(t, P_elec, color=COL_ELEC, linewidth=2.4,
                 label="Electrolyzer power $P_{e,t}$ [kW]")
    l4 = ax.plot(t, E_ge, color=COL_GRID, linestyle="--", linewidth=2.0,
                 label="Grid→Electrolyzer $E_{ge,t}$ [kW]")
    ax.set_ylabel("Power [kW]")
    ax.grid(True, alpha=0.2, linestyle="--")

    # -------------------------
    # (c) SOC + H2 storage
    # -------------------------
    ax = axs[2]
    l5 = ax.plot(t, SOC, color=COL_SOC, linewidth=2.0,
                 label="Battery SOC [kWh]")
    ax.set_ylabel("SOC [kWh]")
    ax.grid(True, alpha=0.2, linestyle="--")

    ax_r = ax.twinx()
    l6 = ax_r.plot(t, H_store, color=COL_H2, linestyle="--", linewidth=2.0,
                   label="H$_2$ storage $H_t$ [kg]")
    ax_r.set_ylabel("H$_2$ storage [kg]")

    axs[2].set_xlabel("Time step $t$ [hour]")

    # -------------------------
    # Global legend outside
    # -------------------------
    lines = l1 + l2 + l3 + l4 + l5 + l6
    labels = [line.get_label() for line in lines]

    fig.legend(lines, labels,
               loc="center left",
               bbox_to_anchor=(1.02, 0.5),
               frameon=False)

    plt.tight_layout(rect=[0, 0, 0.85, 1])

    if savepath:
        plt.savefig(savepath, dpi=300, bbox_inches="tight")

    if show:
        plt.show()

    plt.close(fig)



plot_fig6_rl_timeseries(logs_rl_nf)
